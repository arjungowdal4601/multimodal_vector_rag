# %%
from doc_processor import doc_processor_with_descriptions
from chunking import chunk_markdown_with_llm
from vectorization import ingest_chunks_to_chroma

# %%
pdf_path = "sample.pdf"

# %%
# 1) Generate markdown
processing_doc = doc_processor_with_descriptions(pdf_path)
# Out:
# [INFO] 2026-03-18 18:06:33,957 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-03-18 18:06:33,984 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-03-18 18:06:34,019 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-03-18 18:06:34,019 [RapidOCR] main.py:50: Using C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-03-18 18:06:34,417 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-03-18 18:06:34,417 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-03-18 18:06:34,427 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-03-18 18:06:34,428 [RapidOCR] main.py:50: Using C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-03-18 18:06:34,612 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-03-18 18:06:34,617 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-03-18 18:06:34,664 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-03-18 18:06:34,665 [RapidOCR] main.py:50: Using C:\Users\user\anaconda3\envs\docproc\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth
# Processed 11 page(s) from: sample.pdf
# Final markdown written to: sample_doc_assets\processed_doc.md
# ✅ Finished. Markdown written to: sample_doc_assets\processed_doc.md
#    Folders created: page_images/, image_png_images/, table_images/

# %%
chunking = chunk_markdown_with_llm(pdf_path)

# %%
ingest_chunks_to_chroma(pdf_path="sample.pdf")
# Out:
# 🔄 Generating embeddings from OpenAI...
# ✅ Generated 46 embeddings for 46 documents.
#
# 🎉 DONE — Chunks stored in ChromaDB successfully!
# 📦 Location on disk: vector_db/chroma_db
# 📚 Collection name : embeddings_db
# 📄 PDF name        : sample.pdf
# 🔢 Total chunks    : 46
# 46
